# %% [markdown]
# # init

# %% [markdown]
# ## imports

# %%
import os
import pandas as pd
import warnings
import xgboost as xgb
from xgboost.sklearn import XGBClassifier

from sklearn.ensemble import RandomForestClassifier
warnings.filterwarnings('ignore')

# %% [markdown]
# ## configs

# %%
BASE_PATH = ('/home/shaghayegh/class/ad_click/data/')
DATASET_PATH = BASE_PATH + 'dataset.parquet'
TRAIN_TEST_SPLIT_DATE = '2017-05-11 00:00:00'

FEATURES = [
    'pvalue_level', 'shopping_level', 'price', 'age_level',
    'final_gender_code','user_ad_count', 'user_ad_clk_count',
    'adgroup_count','adgroup_clk_count', 'campaign_count',
    'campaign_clk_count','cate_count', 'cate_clk_count',
    'cat_gender_ad_count','cat_gender_ad_clk_count', 'cat_age_ad_count',
    'cat_age_ad_clk_count','gender_age_ad_count', 'gender_age_ad_clk_count'
]

AD_FEATURES = [
    'price', 'adgroup_count','adgroup_clk_count', 'campaign_count',
    'campaign_clk_count','cate_count', 'cate_clk_count'
]
USER_FEATURES = [
    'pvalue_level', 'shopping_level', 'age_level',
    'final_gender_code','user_ad_count', 'user_ad_clk_count'
]

LABEL = ['clk']

PREDICTION_DATA_PATH = BASE_PATH + 'test.csv'

# %% [markdown]
# # load data

# %%
dataset_df = pd.read_parquet(DATASET_PATH)
dataset_df.head()
# Out:
#    adgroup_id  userid  time_stamp          pid  nonclk  clk  cms_segid  \
# 0          43  824392  1494108093  430548_1007       1    0          0
# 1          69  729782  1494287274  430548_1007       1    0          0
# 2          85   10772  1494393723  430548_1007       1    0          0
# 3          96  765463  1494006071  430539_1007       1    0         35
# 4         100  828934  1494321308  430548_1007       1    0          0
#
#    cms_group_id  pvalue_level  shopping_level  ...  campaign_count  \
# 0             6           NaN               1  ...              10
# 1             8           2.0               3  ...              30
# 2             4           NaN               3  ...              49
# 3             4           2.0               3  ...               0
# 4            10           2.0               2  ...               4
#
#    campaign_clk_count  cate_count  cate_clk_count  cat_gender_ad_count  \
# 0                 2.0       15644           908.0                 7927
# 1                 3.0        1258            95.0                 1057
# 2                 1.0         529            28.0                  334
# 3                 NaN          18             1.0                   13
# 4                 0.0        1184            57.0                 1066
#
#   cat_gender_ad_clk_count  cat_age_ad_count  cat_age_ad_clk_count  \
# 0                   426.0               311                  18.0
# 1                    72.0                62                   3.0
# 2                    15.0               138                   6.0
# 3                     0.0                 5                   0.0
# 4                    52.0               436                  21.0
#
#    gender_age_ad_count gender_age_ad_clk_count
# 0                    0                     NaN
# 1                    0                     NaN
# 2                    0                     NaN
# 3                    0                     NaN
# 4                    0                     NaN
#
# [5 rows x 34 columns]

# %% [markdown]
# # train/test split

# %%
def train_test_split(dataset_df, split_date):
    train_df = dataset_df[dataset_df['time'] < split_date]
    test_df = dataset_df[dataset_df['time'] >= split_date]
    return train_df, test_df

train_df, test_df = train_test_split(dataset_df, TRAIN_TEST_SPLIT_DATE )
train_df.head()
# Out:
#    adgroup_id  userid  time_stamp          pid  nonclk  clk  cms_segid  \
# 0          43  824392  1494108093  430548_1007       1    0          0
# 1          69  729782  1494287274  430548_1007       1    0          0
# 2          85   10772  1494393723  430548_1007       1    0          0
# 3          96  765463  1494006071  430539_1007       1    0         35
# 4         100  828934  1494321308  430548_1007       1    0          0
#
#    cms_group_id  pvalue_level  shopping_level  ...  campaign_count  \
# 0             6           NaN               1  ...              10
# 1             8           2.0               3  ...              30
# 2             4           NaN               3  ...              49
# 3             4           2.0               3  ...               0
# 4            10           2.0               2  ...               4
#
#    campaign_clk_count  cate_count  cate_clk_count  cat_gender_ad_count  \
# 0                 2.0       15644           908.0                 7927
# 1                 3.0        1258            95.0                 1057
# 2                 1.0         529            28.0                  334
# 3                 NaN          18             1.0                   13
# 4                 0.0        1184            57.0                 1066
#
#   cat_gender_ad_clk_count  cat_age_ad_count  cat_age_ad_clk_count  \
# 0                   426.0               311                  18.0
# 1                    72.0                62                   3.0
# 2                    15.0               138                   6.0
# 3                     0.0                 5                   0.0
# 4                    52.0               436                  21.0
#
#    gender_age_ad_count gender_age_ad_clk_count
# 0                    0                     NaN
# 1                    0                     NaN
# 2                    0                     NaN
# 3                    0                     NaN
# 4                    0                     NaN
#
# [5 rows x 34 columns]

# %%
test_df.head()
# Out:
#     adgroup_id   userid  time_stamp          pid  nonclk  clk  cms_segid  \
# 37         102  1122493  1494544665  430539_1007       1    0          0
# 38         102  1030522  1494561308  430539_1007       1    0         82
# 39         102   686384  1494575099  430539_1007       1    0          0
# 40         102   769032  1494577595  430548_1007       1    0         80
# 41         102    83112  1494579892  430539_1007       1    0         80
#
#     cms_group_id  pvalue_level  shopping_level  ...  campaign_count  \
# 37            10           NaN               3  ...             483
# 38            10           3.0               3  ...             510
# 39            10           NaN               3  ...             535
# 40            10           2.0               3  ...             540
# 41            10           2.0               3  ...             545
#
#     campaign_clk_count  cate_count  cate_clk_count  cat_gender_ad_count  \
# 37                20.0        2652           120.0                  437
# 38                20.0        2822           128.0                  452
# 39                20.0        2922           132.0                  464
# 40                20.0        2940           134.0                  466
# 41                20.0        2965           134.0                  469
#
#    cat_gender_ad_clk_count  cat_age_ad_count  cat_age_ad_clk_count  \
# 37                    17.0               972                  49.0
# 38                    18.0              1031                  53.0
# 39                    18.0              1067                  53.0
# 40                    18.0              1077                  54.0
# 41                    18.0              1086                  54.0
#
#     gender_age_ad_count gender_age_ad_clk_count
# 37                   31                     1.0
# 38                   32                     1.0
# 39                   33                     1.0
# 40                   34                     1.0
# 41                   35                     1.0
#
# [5 rows x 34 columns]

# %% [markdown]
# # methods

# %% [markdown]
# ## xgboost

# %% [markdown]
# ### training model 1

# %%
xg1 = XGBClassifier(n_estimators=100, tree_method= 'gpu_hist', scale_pos_weight = 95 / 5)
xg1.fit(train_df[AD_FEATURES], train_df[LABEL])
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ### predict 1

# %%
test_df['Pred_xg1'] = xg1.predict_proba(test_df[AD_FEATURES])[:, 1]
test_df.head()
# Out:
#     adgroup_id   userid  time_stamp          pid  nonclk  clk  cms_segid  \
# 37         102  1122493  1494544665  430539_1007       1    0          0
# 38         102  1030522  1494561308  430539_1007       1    0         82
# 39         102   686384  1494575099  430539_1007       1    0          0
# 40         102   769032  1494577595  430548_1007       1    0         80
# 41         102    83112  1494579892  430539_1007       1    0         80
#
#     cms_group_id  pvalue_level  shopping_level  ...  campaign_clk_count  \
# 37            10           NaN               3  ...                20.0
# 38            10           3.0               3  ...                20.0
# 39            10           NaN               3  ...                20.0
# 40            10           2.0               3  ...                20.0
# 41            10           2.0               3  ...                20.0
#
#     cate_count  cate_clk_count  cat_gender_ad_count  cat_gender_ad_clk_count  \
# 37        2652           120.0                  437                     17.0
# 38        2822           128.0                  452                     18.0
# 39        2922           132.0                  464                     18.0
# 40        2940           134.0                  466                     18.0
# 41        2965           134.0                  469                     18.0
#
#    cat_age_ad_count  cat_age_ad_clk_count  gender_age_ad_count  \
# 37              972                  49.0                   31
# 38             1031                  53.0                   32
# 39             1067                  53.0                   33
# 40             1077                  54.0                   34
# 41             1086                  54.0                   35
#
#     gender_age_ad_clk_count  Pred_xg1
# 37                      1.0  0.425842
# 38                      1.0  0.413324
# 39                      1.0  0.395283
# 40                      1.0  0.395283
# 41                      1.0  0.395283
#
# [5 rows x 35 columns]

# %% [markdown]
# ### training model 2

# %%
xg2 = XGBClassifier(n_estimators=100, tree_method= 'gpu_hist', scale_pos_weight = 95 / 5)
xg2.fit(train_df[USER_FEATURES], train_df[LABEL])
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ### predict 2

# %%
test_df['Pred_xg2'] = xg2.predict_proba(test_df[USER_FEATURES])[:, 1]
test_df.head()
# Out:
#     adgroup_id   userid  time_stamp          pid  nonclk  clk  cms_segid  \
# 37         102  1122493  1494544665  430539_1007       1    0          0
# 38         102  1030522  1494561308  430539_1007       1    0         82
# 39         102   686384  1494575099  430539_1007       1    0          0
# 40         102   769032  1494577595  430548_1007       1    0         80
# 41         102    83112  1494579892  430539_1007       1    0         80
#
#     cms_group_id  pvalue_level  shopping_level  ...  cate_count  \
# 37            10           NaN               3  ...        2652
# 38            10           3.0               3  ...        2822
# 39            10           NaN               3  ...        2922
# 40            10           2.0               3  ...        2940
# 41            10           2.0               3  ...        2965
#
#     cate_clk_count  cat_gender_ad_count  cat_gender_ad_clk_count  \
# 37           120.0                  437                     17.0
# 38           128.0                  452                     18.0
# 39           132.0                  464                     18.0
# 40           134.0                  466                     18.0
# 41           134.0                  469                     18.0
#
#     cat_age_ad_count cat_age_ad_clk_count  gender_age_ad_count  \
# 37               972                 49.0                   31
# 38              1031                 53.0                   32
# 39              1067                 53.0                   33
# 40              1077                 54.0                   34
# 41              1086                 54.0                   35
#
#     gender_age_ad_clk_count  Pred_xg1  Pred_xg2
# 37                      1.0  0.425842  0.425445
# 38                      1.0  0.413324  0.557408
# 39                      1.0  0.395283  0.429266
# 40                      1.0  0.395283  0.314430
# 41                      1.0  0.395283  0.471036
#
# [5 rows x 36 columns]

# %% [markdown]
# ### training model 3

# %%
xg3 = XGBClassifier(n_estimators=100, tree_method= 'gpu_hist', scale_pos_weight = 95 / 5)
xg3.fit(train_df[FEATURES], train_df[LABEL])
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ### predict 3

# %%
test_df['Pred_xg3'] = xg3.predict_proba(test_df[FEATURES])[:, 1]
test_df.head()
# Out:
#     adgroup_id   userid  time_stamp          pid  nonclk  clk  cms_segid  \
# 37         102  1122493  1494544665  430539_1007       1    0          0
# 38         102  1030522  1494561308  430539_1007       1    0         82
# 39         102   686384  1494575099  430539_1007       1    0          0
# 40         102   769032  1494577595  430548_1007       1    0         80
# 41         102    83112  1494579892  430539_1007       1    0         80
#
#     cms_group_id  pvalue_level  shopping_level  ...  cate_clk_count  \
# 37            10           NaN               3  ...           120.0
# 38            10           3.0               3  ...           128.0
# 39            10           NaN               3  ...           132.0
# 40            10           2.0               3  ...           134.0
# 41            10           2.0               3  ...           134.0
#
#     cat_gender_ad_count  cat_gender_ad_clk_count  cat_age_ad_count  \
# 37                  437                     17.0               972
# 38                  452                     18.0              1031
# 39                  464                     18.0              1067
# 40                  466                     18.0              1077
# 41                  469                     18.0              1086
#
#     cat_age_ad_clk_count gender_age_ad_count  gender_age_ad_clk_count  \
# 37                  49.0                  31                      1.0
# 38                  53.0                  32                      1.0
# 39                  53.0                  33                      1.0
# 40                  54.0                  34                      1.0
# 41                  54.0                  35                      1.0
#
#     Pred_xg1  Pred_xg2  Pred_xg3
# 37  0.425842  0.425445  0.361358
# 38  0.413324  0.557408  0.347493
# 39  0.395283  0.429266  0.356536
# 40  0.395283  0.314430  0.282013
# 41  0.395283  0.471036  0.398434
#
# [5 rows x 37 columns]

# %% [markdown]
# # save prediction

# %%
test_df.to_csv(PREDICTION_DATA_PATH, index=False)
