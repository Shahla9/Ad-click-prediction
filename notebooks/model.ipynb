# %% [markdown]
# # init

# %% [markdown]
# ## imports

# %%
import os
import pandas as pd
import warnings
import xgboost as xgb
from xgboost.sklearn import XGBClassifier

from sklearn.ensemble import RandomForestClassifier
warnings.filterwarnings('ignore')

# %% [markdown]
# ## configs

# %%
BASE_PATH = ('/home/shaghayegh/class/ad_click/data/')
DATASET_PATH = BASE_PATH + 'dataset.parquet'
TRAIN_TEST_SPLIT_DATE = '2017-05-11 00:00:00'

FEATURES = [
    'pvalue_level', 'shopping_level', 'price', 'age_level',
    'final_gender_code','user_ad_count', 'user_ad_clk_count',
    'adgroup_count','adgroup_clk_count', 'campaign_count',
    'campaign_clk_count','cate_count', 'cate_clk_count',
    'cat_gender_ad_count','cat_gender_ad_clk_count', 'cat_age_ad_count',
    'cat_age_ad_clk_count','gender_age_ad_count', 'gender_age_ad_clk_count'
]

AD_FEATURES = [
    'price', 'adgroup_count','adgroup_clk_count', 'campaign_count',
    'campaign_clk_count','cate_count', 'cate_clk_count'
]
USER_FEATURES = [
    'pvalue_level', 'shopping_level', 'age_level',
    'final_gender_code','user_ad_count', 'user_ad_clk_count'
]

LABEL = ['clk']

PREDICTION_DATA_PATH = BASE_PATH + 'test.csv'

# %% [markdown]
# # load data

# %%
dataset_df = pd.read_parquet(DATASET_PATH)
dataset_df
# Out:
#           adgroup_id   userid  time_stamp          pid  nonclk  clk  \
# 0                 43   824392  1494108093  430548_1007       1    0
# 1                 69   729782  1494287274  430548_1007       1    0
# 2                 85    10772  1494393723  430548_1007       1    0
# 3                 96   765463  1494006071  430539_1007       1    0
# 4                100   828934  1494321308  430548_1007       1    0
# ...              ...      ...         ...          ...     ...  ...
# 25029430      846708  1131637  1494313604  430539_1007       1    0
# 25029431      846725   905008  1494341113  430548_1007       1    0
# 25029432      846794   149286  1494006221  430548_1007       1    0
# 25029433      846794   313387  1494110329  430548_1007       1    0
# 25029434      846794   404264  1494444088  430548_1007       0    1
#
#           cms_segid  cms_group_id  pvalue_level  shopping_level  ...  \
# 0                 0             6           NaN               1  ...
# 1                 0             8           2.0               3  ...
# 2                 0             4           NaN               3  ...
# 3                35             4           2.0               3  ...
# 4                 0            10           2.0               2  ...
# ...             ...           ...           ...             ...  ...
# 25029430          0             6           NaN               1  ...
# 25029431         57             8           1.0               3  ...
# 25029432          0             4           NaN               3  ...
# 25029433         30             4           1.0               3  ...
# 25029434          0             5           NaN               3  ...
#
#           campaign_count  campaign_clk_count  cate_count  cate_clk_count  \
# 0                     10                 2.0       15644           908.0
# 1                     30                 3.0        1258            95.0
# 2                     49                 1.0         529            28.0
# 3                      0                 NaN          18             1.0
# 4                      4                 0.0        1184            57.0
# ...                  ...                 ...         ...             ...
# 25029430              13                 0.0       17132          1016.0
# 25029431               3                 0.0        1045            45.0
# 25029432               0                 NaN          15             0.0
# 25029433               3                 0.0         485            14.0
# 25029434              11                 0.0        2389           105.0
#
#           cat_gender_ad_count cat_gender_ad_clk_count  cat_age_ad_count  \
# 0                        7927                   426.0               311
# 1                        1057                    72.0                62
# 2                         334                    15.0               138
# 3                          13                     0.0                 5
# 4                        1066                    52.0               436
# ...                       ...                     ...               ...
# 25029430                14548                   852.0               276
# 25029431                  897                    41.0               485
# 25029432                    4                     0.0                 5
# 25029433                  128                     6.0               105
# 25029434                  637                    26.0               620
#
#           cat_age_ad_clk_count  gender_age_ad_count gender_age_ad_clk_count
# 0                         18.0                    0                     NaN
# 1                          3.0                    0                     NaN
# 2                          6.0                    0                     NaN
# 3                          0.0                    0                     NaN
# 4                         21.0                    0                     NaN
# ...                        ...                  ...                     ...
# 25029430                  12.0                    1                     0.0
# 25029431                  19.0                    0                     NaN
# 25029432                   0.0                    0                     NaN
# 25029433                   2.0                    1                     0.0
# 25029434                  38.0                    0                     NaN
#
# [25029435 rows x 34 columns]

# %% [markdown]
# # train/test split

# %%
def train_test_split(dataset_df, split_date):
    train_df = dataset_df[dataset_df['time'] < split_date]
    test_df = dataset_df[dataset_df['time'] >= split_date]
    return train_df, test_df

train_df, test_df = train_test_split(dataset_df, TRAIN_TEST_SPLIT_DATE )
train_df
# Out:
#           adgroup_id   userid  time_stamp          pid  nonclk  clk  \
# 0                 43   824392  1494108093  430548_1007       1    0
# 1                 69   729782  1494287274  430548_1007       1    0
# 2                 85    10772  1494393723  430548_1007       1    0
# 3                 96   765463  1494006071  430539_1007       1    0
# 4                100   828934  1494321308  430548_1007       1    0
# ...              ...      ...         ...          ...     ...  ...
# 25029430      846708  1131637  1494313604  430539_1007       1    0
# 25029431      846725   905008  1494341113  430548_1007       1    0
# 25029432      846794   149286  1494006221  430548_1007       1    0
# 25029433      846794   313387  1494110329  430548_1007       1    0
# 25029434      846794   404264  1494444088  430548_1007       0    1
#
#           cms_segid  cms_group_id  pvalue_level  shopping_level  ...  \
# 0                 0             6           NaN               1  ...
# 1                 0             8           2.0               3  ...
# 2                 0             4           NaN               3  ...
# 3                35             4           2.0               3  ...
# 4                 0            10           2.0               2  ...
# ...             ...           ...           ...             ...  ...
# 25029430          0             6           NaN               1  ...
# 25029431         57             8           1.0               3  ...
# 25029432          0             4           NaN               3  ...
# 25029433         30             4           1.0               3  ...
# 25029434          0             5           NaN               3  ...
#
#           campaign_count  campaign_clk_count  cate_count  cate_clk_count  \
# 0                     10                 2.0       15644           908.0
# 1                     30                 3.0        1258            95.0
# 2                     49                 1.0         529            28.0
# 3                      0                 NaN          18             1.0
# 4                      4                 0.0        1184            57.0
# ...                  ...                 ...         ...             ...
# 25029430              13                 0.0       17132          1016.0
# 25029431               3                 0.0        1045            45.0
# 25029432               0                 NaN          15             0.0
# 25029433               3                 0.0         485            14.0
# 25029434              11                 0.0        2389           105.0
#
#           cat_gender_ad_count cat_gender_ad_clk_count  cat_age_ad_count  \
# 0                        7927                   426.0               311
# 1                        1057                    72.0                62
# 2                         334                    15.0               138
# 3                          13                     0.0                 5
# 4                        1066                    52.0               436
# ...                       ...                     ...               ...
# 25029430                14548                   852.0               276
# 25029431                  897                    41.0               485
# 25029432                    4                     0.0                 5
# 25029433                  128                     6.0               105
# 25029434                  637                    26.0               620
#
#           cat_age_ad_clk_count  gender_age_ad_count gender_age_ad_clk_count
# 0                         18.0                    0                     NaN
# 1                          3.0                    0                     NaN
# 2                          6.0                    0                     NaN
# 3                          0.0                    0                     NaN
# 4                         21.0                    0                     NaN
# ...                        ...                  ...                     ...
# 25029430                  12.0                    1                     0.0
# 25029431                  19.0                    0                     NaN
# 25029432                   0.0                    0                     NaN
# 25029433                   2.0                    1                     0.0
# 25029434                  38.0                    0                     NaN
#
# [17275680 rows x 34 columns]

# %%
test_df
# Out:
#           adgroup_id   userid  time_stamp          pid  nonclk  clk  \
# 37               102  1122493  1494544665  430539_1007       1    0
# 38               102  1030522  1494561308  430539_1007       1    0
# 39               102   686384  1494575099  430539_1007       1    0
# 40               102   769032  1494577595  430548_1007       1    0
# 41               102    83112  1494579892  430539_1007       1    0
# ...              ...      ...         ...          ...     ...  ...
# 25029408      846620   618896  1494673481  430548_1007       1    0
# 25029409      846620   812936  1494684147  430539_1007       1    0
# 25029422      846643    24187  1494487104  430548_1007       1    0
# 25029423      846643   873656  1494566205  430548_1007       1    0
# 25029424      846643   849823  1494566901  430548_1007       1    0
#
#           cms_segid  cms_group_id  pvalue_level  shopping_level  ...  \
# 37                0            10           NaN               3  ...
# 38               82            10           3.0               3  ...
# 39                0            10           NaN               3  ...
# 40               80            10           2.0               3  ...
# 41               80            10           2.0               3  ...
# ...             ...           ...           ...             ...  ...
# 25029408          0             4           NaN               2  ...
# 25029409         33             4           2.0               3  ...
# 25029422         92            11           2.0               3  ...
# 25029423          0            11           NaN               3  ...
# 25029424          0            11           NaN               3  ...
#
#           campaign_count  campaign_clk_count  cate_count  cate_clk_count  \
# 37                   483                20.0        2652           120.0
# 38                   510                20.0        2822           128.0
# 39                   535                20.0        2922           132.0
# 40                   540                20.0        2940           134.0
# 41                   545                20.0        2965           134.0
# ...                  ...                 ...         ...             ...
# 25029408              79                 4.0      264603         12920.0
# 25029409              80                 4.0      270152         13187.0
# 25029422              46                 1.0        3318           174.0
# 25029423              56                 1.0        3737           195.0
# 25029424              57                 1.0        3744           195.0
#
#           cat_gender_ad_count cat_gender_ad_clk_count  cat_age_ad_count  \
# 37                        437                    17.0               972
# 38                        452                    18.0              1031
# 39                        464                    18.0              1067
# 40                        466                    18.0              1077
# 41                        469                    18.0              1086
# ...                       ...                     ...               ...
# 25029408               231953                 11284.0             58874
# 25029409               236803                 11519.0             60119
# 25029422                 3044                   158.0              1050
# 25029423                 3400                   175.0              1201
# 25029424                 3406                   175.0              1203
#
#           cat_age_ad_clk_count  gender_age_ad_count gender_age_ad_clk_count
# 37                        49.0                   31                     1.0
# 38                        53.0                   32                     1.0
# 39                        53.0                   33                     1.0
# 40                        54.0                   34                     1.0
# 41                        54.0                   35                     1.0
# ...                        ...                  ...                     ...
# 25029408                2890.0                   23                     2.0
# 25029409                2944.0                   24                     2.0
# 25029422                  65.0                   11                     0.0
# 25029423                  73.0                   12                     0.0
# 25029424                  73.0                   13                     0.0
#
# [7753755 rows x 34 columns]

# %% [markdown]
# # methods

# %% [markdown]
# ## xgboost

# %% [markdown]
# ### training model 1

# %%
xg1 = XGBClassifier(n_estimators=100, tree_method= 'gpu_hist', scale_pos_weight = 95 / 5)
xg1.fit(train_df[AD_FEATURES], train_df[LABEL])
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ### predict 1

# %%
test_df['Pred_xg1'] = xg1.predict_proba(test_df[AD_FEATURES])[:, 1]
test_df
# Out:
#           adgroup_id   userid  time_stamp          pid  nonclk  clk  \
# 37               102  1122493  1494544665  430539_1007       1    0
# 38               102  1030522  1494561308  430539_1007       1    0
# 39               102   686384  1494575099  430539_1007       1    0
# 40               102   769032  1494577595  430548_1007       1    0
# 41               102    83112  1494579892  430539_1007       1    0
# ...              ...      ...         ...          ...     ...  ...
# 25029408      846620   618896  1494673481  430548_1007       1    0
# 25029409      846620   812936  1494684147  430539_1007       1    0
# 25029422      846643    24187  1494487104  430548_1007       1    0
# 25029423      846643   873656  1494566205  430548_1007       1    0
# 25029424      846643   849823  1494566901  430548_1007       1    0
#
#           cms_segid  cms_group_id  pvalue_level  shopping_level  ...  \
# 37                0            10           NaN               3  ...
# 38               82            10           3.0               3  ...
# 39                0            10           NaN               3  ...
# 40               80            10           2.0               3  ...
# 41               80            10           2.0               3  ...
# ...             ...           ...           ...             ...  ...
# 25029408          0             4           NaN               2  ...
# 25029409         33             4           2.0               3  ...
# 25029422         92            11           2.0               3  ...
# 25029423          0            11           NaN               3  ...
# 25029424          0            11           NaN               3  ...
#
#           campaign_clk_count  cate_count  cate_clk_count  cat_gender_ad_count  \
# 37                      20.0        2652           120.0                  437
# 38                      20.0        2822           128.0                  452
# 39                      20.0        2922           132.0                  464
# 40                      20.0        2940           134.0                  466
# 41                      20.0        2965           134.0                  469
# ...                      ...         ...             ...                  ...
# 25029408                 4.0      264603         12920.0               231953
# 25029409                 4.0      270152         13187.0               236803
# 25029422                 1.0        3318           174.0                 3044
# 25029423                 1.0        3737           195.0                 3400
# 25029424                 1.0        3744           195.0                 3406
#
#           cat_gender_ad_clk_count cat_age_ad_count  cat_age_ad_clk_count  \
# 37                           17.0              972                  49.0
# 38                           18.0             1031                  53.0
# 39                           18.0             1067                  53.0
# 40                           18.0             1077                  54.0
# 41                           18.0             1086                  54.0
# ...                           ...              ...                   ...
# 25029408                  11284.0            58874                2890.0
# 25029409                  11519.0            60119                2944.0
# 25029422                    158.0             1050                  65.0
# 25029423                    175.0             1201                  73.0
# 25029424                    175.0             1203                  73.0
#
#           gender_age_ad_count  gender_age_ad_clk_count  Pred_xg1
# 37                         31                      1.0  0.425842
# 38                         32                      1.0  0.413324
# 39                         33                      1.0  0.395283
# 40                         34                      1.0  0.395283
# 41                         35                      1.0  0.395283
# ...                       ...                      ...       ...
# 25029408                   23                      2.0  0.501496
# 25029409                   24                      2.0  0.501496
# 25029422                   11                      0.0  0.475533
# 25029423                   12                      0.0  0.478228
# 25029424                   13                      0.0  0.476271
#
# [7753755 rows x 35 columns]

# %% [markdown]
# ### training model 2

# %%
xg2 = XGBClassifier(n_estimators=100, tree_method= 'gpu_hist', scale_pos_weight = 95 / 5)
xg2.fit(train_df[USER_FEATURES], train_df[LABEL])
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ### predict 2

# %%
test_df['Pred_xg2'] = xg2.predict_proba(test_df[USER_FEATURES])[:, 1]
test_df
# Out:
#           adgroup_id   userid  time_stamp          pid  nonclk  clk  \
# 37               102  1122493  1494544665  430539_1007       1    0
# 38               102  1030522  1494561308  430539_1007       1    0
# 39               102   686384  1494575099  430539_1007       1    0
# 40               102   769032  1494577595  430548_1007       1    0
# 41               102    83112  1494579892  430539_1007       1    0
# ...              ...      ...         ...          ...     ...  ...
# 25029408      846620   618896  1494673481  430548_1007       1    0
# 25029409      846620   812936  1494684147  430539_1007       1    0
# 25029422      846643    24187  1494487104  430548_1007       1    0
# 25029423      846643   873656  1494566205  430548_1007       1    0
# 25029424      846643   849823  1494566901  430548_1007       1    0
#
#           cms_segid  cms_group_id  pvalue_level  shopping_level  ...  \
# 37                0            10           NaN               3  ...
# 38               82            10           3.0               3  ...
# 39                0            10           NaN               3  ...
# 40               80            10           2.0               3  ...
# 41               80            10           2.0               3  ...
# ...             ...           ...           ...             ...  ...
# 25029408          0             4           NaN               2  ...
# 25029409         33             4           2.0               3  ...
# 25029422         92            11           2.0               3  ...
# 25029423          0            11           NaN               3  ...
# 25029424          0            11           NaN               3  ...
#
#           cate_count  cate_clk_count  cat_gender_ad_count  \
# 37              2652           120.0                  437
# 38              2822           128.0                  452
# 39              2922           132.0                  464
# 40              2940           134.0                  466
# 41              2965           134.0                  469
# ...              ...             ...                  ...
# 25029408      264603         12920.0               231953
# 25029409      270152         13187.0               236803
# 25029422        3318           174.0                 3044
# 25029423        3737           195.0                 3400
# 25029424        3744           195.0                 3406
#
#           cat_gender_ad_clk_count  cat_age_ad_count cat_age_ad_clk_count  \
# 37                           17.0               972                 49.0
# 38                           18.0              1031                 53.0
# 39                           18.0              1067                 53.0
# 40                           18.0              1077                 54.0
# 41                           18.0              1086                 54.0
# ...                           ...               ...                  ...
# 25029408                  11284.0             58874               2890.0
# 25029409                  11519.0             60119               2944.0
# 25029422                    158.0              1050                 65.0
# 25029423                    175.0              1201                 73.0
# 25029424                    175.0              1203                 73.0
#
#           gender_age_ad_count  gender_age_ad_clk_count  Pred_xg1  Pred_xg2
# 37                         31                      1.0  0.425842  0.425445
# 38                         32                      1.0  0.413324  0.557408
# 39                         33                      1.0  0.395283  0.429266
# 40                         34                      1.0  0.395283  0.314430
# 41                         35                      1.0  0.395283  0.471036
# ...                       ...                      ...       ...       ...
# 25029408                   23                      2.0  0.501496  0.433991
# 25029409                   24                      2.0  0.501496  0.464703
# 25029422                   11                      0.0  0.475533  0.501097
# 25029423                   12                      0.0  0.478228  0.529030
# 25029424                   13                      0.0  0.476271  0.479522
#
# [7753755 rows x 36 columns]

# %% [markdown]
# ### training model 3

# %%
xg3 = XGBClassifier(n_estimators=100, tree_method= 'gpu_hist', scale_pos_weight = 95 / 5)
xg3.fit(train_df[FEATURES], train_df[LABEL])
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ### predict 3

# %%
test_df['Pred_xg3'] = xg3.predict_proba(test_df[FEATURES])[:, 1]
test_df
# Out:
#           adgroup_id   userid  time_stamp          pid  nonclk  clk  \
# 37               102  1122493  1494544665  430539_1007       1    0
# 38               102  1030522  1494561308  430539_1007       1    0
# 39               102   686384  1494575099  430539_1007       1    0
# 40               102   769032  1494577595  430548_1007       1    0
# 41               102    83112  1494579892  430539_1007       1    0
# ...              ...      ...         ...          ...     ...  ...
# 25029408      846620   618896  1494673481  430548_1007       1    0
# 25029409      846620   812936  1494684147  430539_1007       1    0
# 25029422      846643    24187  1494487104  430548_1007       1    0
# 25029423      846643   873656  1494566205  430548_1007       1    0
# 25029424      846643   849823  1494566901  430548_1007       1    0
#
#           cms_segid  cms_group_id  pvalue_level  shopping_level  ...  \
# 37                0            10           NaN               3  ...
# 38               82            10           3.0               3  ...
# 39                0            10           NaN               3  ...
# 40               80            10           2.0               3  ...
# 41               80            10           2.0               3  ...
# ...             ...           ...           ...             ...  ...
# 25029408          0             4           NaN               2  ...
# 25029409         33             4           2.0               3  ...
# 25029422         92            11           2.0               3  ...
# 25029423          0            11           NaN               3  ...
# 25029424          0            11           NaN               3  ...
#
#           cate_clk_count  cat_gender_ad_count  cat_gender_ad_clk_count  \
# 37                 120.0                  437                     17.0
# 38                 128.0                  452                     18.0
# 39                 132.0                  464                     18.0
# 40                 134.0                  466                     18.0
# 41                 134.0                  469                     18.0
# ...                  ...                  ...                      ...
# 25029408         12920.0               231953                  11284.0
# 25029409         13187.0               236803                  11519.0
# 25029422           174.0                 3044                    158.0
# 25029423           195.0                 3400                    175.0
# 25029424           195.0                 3406                    175.0
#
#           cat_age_ad_count  cat_age_ad_clk_count gender_age_ad_count  \
# 37                     972                  49.0                  31
# 38                    1031                  53.0                  32
# 39                    1067                  53.0                  33
# 40                    1077                  54.0                  34
# 41                    1086                  54.0                  35
# ...                    ...                   ...                 ...
# 25029408             58874                2890.0                  23
# 25029409             60119                2944.0                  24
# 25029422              1050                  65.0                  11
# 25029423              1201                  73.0                  12
# 25029424              1203                  73.0                  13
#
#           gender_age_ad_clk_count  Pred_xg1  Pred_xg2  Pred_xg3
# 37                            1.0  0.425842  0.425445  0.361358
# 38                            1.0  0.413324  0.557408  0.347493
# 39                            1.0  0.395283  0.429266  0.356536
# 40                            1.0  0.395283  0.314430  0.282013
# 41                            1.0  0.395283  0.471036  0.398434
# ...                           ...       ...       ...       ...
# 25029408                      2.0  0.501496  0.433991  0.402419
# 25029409                      2.0  0.501496  0.464703  0.463746
# 25029422                      0.0  0.475533  0.501097  0.464452
# 25029423                      0.0  0.478228  0.529030  0.530012
# 25029424                      0.0  0.476271  0.479522  0.432176
#
# [7753755 rows x 37 columns]

# %% [markdown]
# # save prediction

# %%
test_df.to_csv(PREDICTION_DATA_PATH, index=False)
